# %%
from veriff.reporting import classifier_full_report
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Generate dataset in pandas dataframe
num_dp = 100
confidences = np.append(
    np.random.normal(0.3, 0.2, num_dp).flatten(),
    np.random.normal(0.7, 0.2, num_dp).flatten() , axis=0
    )

labels = np.append(
    [ 0 for _ in range(num_dp)],
    [ 1 for _ in range(num_dp)], axis=0
    )

random_value = np.random.randint(0, 10000, num_dp * 2)

labels = labels.astype(bool)
report_df = pd.DataFrame({'confidence': confidences, 'label': labels, 'dp_data': random_value})

# %%
# user code: 
def display_image( row ):
    np.random.seed( row['dp_data'] ) # reads values from row
    plt.imshow( np.random.rand( 100, 100 ) )

classifier_full_report( report_df, display_lambda=display_image )
# Out:
# Now showing random datapoints from dataset:
# cutoff point was not given, defaulting to 0.5
# Now showing FP predictions from dataset:
# Now showing FN predictions from dataset:
